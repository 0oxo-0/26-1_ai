# %%
# 데이터 불러오기

import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/breast_cancer.csv'
df = pd.read_csv(path)

# %%
# 데이터 출력해서 확인
df.head()
# Out:
#    Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0           0        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           2        19.69         21.25          130.00     1203.0
# 3           3        11.42         20.38           77.58      386.1
# 4           4        20.29         14.34          135.10     1297.0
#
#    mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 32 columns]

# %%
#label, feature 데이터 입력하

y=df['mean radius']

X=df.drop('mean radius',axis=1)

# %%
y.value_counts()
X.head()
# Out:
#    Unnamed: 0  mean texture  mean perimeter  mean area  mean smoothness  \
# 0           0         10.38          122.80     1001.0          0.11840
# 1           1         17.77          132.90     1326.0          0.08474
# 2           2         21.25          130.00     1203.0          0.10960
# 3           3         20.38           77.58      386.1          0.14250
# 4           4         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
# numpy 변환
X = X.values # 엑셀 형태 → 숫자 배열로 변환하기 위해 사

# 정규화 (데이터를 비슷한 범위로 맞추는 작업)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# %%
from tensorflow.keras import layers, models
# 층(layer)을 순서대로 쌓는 모델, 입력 → 은닉층 → 출력층으로 일직선 구조

model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)), # 첫 번째 층 (입력층 + 은닉층),
    # 뉴런(노드) 64개, 입력 데이터의 컬럼 개수, activation="relu" <- 활성화 함수
    layers.Dropout(0.3), # 30% 뉴런을 랜덤으로 off > 과적합 방지
    layers.Dense(32, activation="relu"),# 두 번째 은닉층, 뉴런을 64 → 32로 줄이면서 중요한 정보만 남김
    layers.Dense(1)
    # Y.shape[1] = 클래스 개수, softmax = 확률로 변환
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 컴파일
model.compile(
    optimizer="adam", # 가중치 업데이트 방법, 자동으로 학습률 조정
    loss="mae",
    metrics=["mae"] # 평가 척
)

# %%
# 모델학습
history = model.fit(
    X_train, y_train,
    validation_split=0.2, # 학습 데이터 중 20%를 검증용으로 사용
    epochs=50, # 전체 데이터를 50번 반복 학습
    batch_size=16, # 한 번에 16개씩 학습
    verbose=1 # 학습 과정 출력
)
# Out:
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 12.4226 - mae: 12.4226 - val_loss: 11.5188 - val_mae: 11.5188
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6022 - mae: 9.6022 - val_loss: 7.8655 - val_mae: 7.8655
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9876 - mae: 5.9876 - val_loss: 4.5785 - val_mae: 4.5785
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3182 - mae: 4.3182 - val_loss: 4.1205 - val_mae: 4.1205
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6295 - mae: 3.6295 - val_loss: 3.6776 - val_mae: 3.6776
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2618 - mae: 3.2618 - val_loss: 3.3697 - val_mae: 3.3697
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0286 - mae: 3.0286 - val_loss: 3.4037 - val_mae: 3.4037
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9056 - mae: 2.9056 - val_loss: 3.0762 - val_mae: 3.0762
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7350 - mae: 2.7350 - val_loss: 2.9297 - val_mae: 2.9297
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5214 - mae: 2.5214 - val_loss: 2.6497 - val_mae: 2.6497
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5309 - mae: 2.5309 - val_loss: 2.5356 - val_mae: 2.5356
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3809 - mae: 2.3809 - val_loss: 2.5174 - val_mae: 2.5174
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2287 - mae: 2.2287 - val_loss: 2.3048 - val_mae: 2.3048
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3970 - mae: 2.3970 - val_loss: 2.2336 - val_mae: 2.2336
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1573 - mae: 2.1573 - val_loss: 2.1538 - val_mae: 2.1538
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1429 - mae: 2.1429 - val_loss: 1.9984 - val_mae: 1.9984
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0615 - mae: 2.0615 - val_loss: 1.9487 - val_mae: 1.9487
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0573 - mae: 2.0573 - val_loss: 1.9017 - val_mae: 1.9017
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9605 - mae: 1.9605 - val_loss: 1.8629 - val_mae: 1.8629
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9996 - mae: 1.9996 - val_loss: 1.8043 - val_mae: 1.8043
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9473 - mae: 1.9473 - val_loss: 2.0111 - val_mae: 2.0111
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9391 - mae: 1.9391 - val_loss: 1.8593 - val_mae: 1.8593
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9282 - mae: 1.9282 - val_loss: 1.8047 - val_mae: 1.8047
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9071 - mae: 1.9071 - val_loss: 1.5986 - val_mae: 1.5986
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6796 - mae: 1.6796 - val_loss: 1.6042 - val_mae: 1.6042
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7630 - mae: 1.7630 - val_loss: 1.5447 - val_mae: 1.5447
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7198 - mae: 1.7198 - val_loss: 1.5360 - val_mae: 1.5360
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6098 - mae: 1.6098 - val_loss: 1.4570 - val_mae: 1.4570
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6710 - mae: 1.6710 - val_loss: 1.5092 - val_mae: 1.5092
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6188 - mae: 1.6188 - val_loss: 1.3274 - val_mae: 1.3274
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6125 - mae: 1.6125 - val_loss: 1.4827 - val_mae: 1.4827
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6939 - mae: 1.6939 - val_loss: 1.2253 - val_mae: 1.2253
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6310 - mae: 1.6310 - val_loss: 1.5443 - val_mae: 1.5443
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6552 - mae: 1.6552 - val_loss: 1.2616 - val_mae: 1.2616
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4898 - mae: 1.4898 - val_loss: 1.4418 - val_mae: 1.4418
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5560 - mae: 1.5560 - val_loss: 1.3280 - val_mae: 1.3280
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4808 - mae: 1.4808 - val_loss: 1.1826 - val_mae: 1.1826
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4619 - mae: 1.4619 - val_loss: 1.2001 - val_mae: 1.2001
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4224 - mae: 1.4224 - val_loss: 1.2369 - val_mae: 1.2369
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4424 - mae: 1.4424 - val_loss: 1.0503 - val_mae: 1.0503
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4023 - mae: 1.4023 - val_loss: 1.1679 - val_mae: 1.1679
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3671 - mae: 1.3671 - val_loss: 1.2004 - val_mae: 1.2004
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4326 - mae: 1.4326 - val_loss: 1.1426 - val_mae: 1.1426
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4539 - mae: 1.4539 - val_loss: 1.0798 - val_mae: 1.0798
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2870 - mae: 1.2870 - val_loss: 1.0006 - val_mae: 1.0006
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3179 - mae: 1.3179 - val_loss: 0.9988 - val_mae: 0.9988
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3238 - mae: 1.3238 - val_loss: 1.0346 - val_mae: 1.0346
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2765 - mae: 1.2765 - val_loss: 1.0536 - val_mae: 1.0536
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2768 - mae: 1.2768 - val_loss: 1.0060 - val_mae: 1.0060
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2415 - mae: 1.2415 - val_loss: 0.9116 - val_mae: 0.9116

# %%
y_pred = model.predict(X_test) # 결과 = 확률
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79fa9a916980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
# 그래프 그리기용 데이터 저장
loss = history.history['loss']
val_loss = history.history['val_loss']
mae = history.history['mae']
val_mae = history.history['val_mae']

# %%
# 학습 과정에서 손실(loss)이 어떻게 변하는지 시각화

import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error


loss = history.history['loss'] # loss = 훈련 데이터 오차 /
val_loss = history.history['val_loss'] # val_loss = 검증 데이터 오차
# history는 model.fit() 결과

mae = history.history['mae']
val_mae = history.history['val_mae'] # 결과 척

epochs = range(1, len(loss) + 1) # x축 만들기

plt.plot(epochs, loss, 'y', label='Training loss') # 훈련 데이터 손실
# x축: epoch y축: loss 'y': 노란색
plt.plot(epochs, val_loss, 'r', label='Validation loss') # 검증 데이터 손실
# 'r': 빨간색
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs, mae, 'y', label='Training MAE')
plt.plot(epochs, val_mae, 'r', label='Validation MAE')
plt.title('Training and validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# MAE : 0.8827247785554898
# MSE : 1.5550094941805754
# RMSE: 1.2470001981477692
