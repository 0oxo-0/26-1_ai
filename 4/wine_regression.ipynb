# %%
# 데이터 불러오기

import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/wine.csv'
df = pd.read_csv(path)

# %%
# 데이터 출력해서 확인
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
#label, feature 데이터 입력하

y=df['Alcohol']

X=df.drop('Alcohol',axis=1)

# %%
y.value_counts()
X.head()
# Out:
#    Wine  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1        1.71  2.43  15.6  127     2.80        3.06
# 1     1        1.78  2.14  11.2  100     2.65        2.76
# 2     1        2.36  2.67  18.6  101     2.80        3.24
# 3     1        1.95  2.50  16.8  113     3.85        3.49
# 4     1        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
# numpy 변환
X = X.values # 엑셀 형태 → 숫자 배열로 변환하기 위해 사

# 정규화 (데이터를 비슷한 범위로 맞추는 작업)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# %%
from tensorflow.keras import layers, models
# 층(layer)을 순서대로 쌓는 모델, 입력 → 은닉층 → 출력층으로 일직선 구조

model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)), # 첫 번째 층 (입력층 + 은닉층),
    # 뉴런(노드) 64개, 입력 데이터의 컬럼 개수, activation="relu" <- 활성화 함수
    layers.Dropout(0.3), # 30% 뉴런을 랜덤으로 off > 과적합 방지
    layers.Dense(32, activation="relu"),# 두 번째 은닉층, 뉴런을 64 → 32로 줄이면서 중요한 정보만 남김
    layers.Dense(1)
    # Y.shape[1] = 클래스 개수, softmax = 확률로 변환
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 컴파일
model.compile(
    optimizer="adam", # 가중치 업데이트 방법, 자동으로 학습률 조정
    loss="mae",
    metrics=["mae"] # 평가 척
)

# %%
# 모델학습
history = model.fit(
    X_train, y_train,
    validation_split=0.2, # 학습 데이터 중 20%를 검증용으로 사용
    epochs=50, # 전체 데이터를 50번 반복 학습
    batch_size=16, # 한 번에 16개씩 학습
    verbose=1 # 학습 과정 출력
)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 13.3616 - mae: 13.3616 - val_loss: 12.7723 - val_mae: 12.7723
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.7470 - mae: 12.7470 - val_loss: 12.2649 - val_mae: 12.2649
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.1979 - mae: 12.1979 - val_loss: 11.7431 - val_mae: 11.7431
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.6693 - mae: 11.6693 - val_loss: 11.1737 - val_mae: 11.1737
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 10.9412 - mae: 10.9412 - val_loss: 10.5338 - val_mae: 10.5338
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.2498 - mae: 10.2498 - val_loss: 9.7975 - val_mae: 9.7975
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4698 - mae: 9.4698 - val_loss: 8.9299 - val_mae: 8.9299
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4859 - mae: 8.4859 - val_loss: 7.8779 - val_mae: 7.8779
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0555 - mae: 7.0555 - val_loss: 6.6098 - val_mae: 6.6098
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5355 - mae: 5.5355 - val_loss: 5.1044 - val_mae: 5.1044
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1798 - mae: 4.1798 - val_loss: 3.4119 - val_mae: 3.4119
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9998 - mae: 2.9998 - val_loss: 2.1242 - val_mae: 2.1242
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6662 - mae: 2.6662 - val_loss: 1.8918 - val_mae: 1.8918
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2734 - mae: 2.2734 - val_loss: 1.8088 - val_mae: 1.8088
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3054 - mae: 2.3054 - val_loss: 1.7895 - val_mae: 1.7895
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2134 - mae: 2.2134 - val_loss: 1.7343 - val_mae: 1.7343
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.3381 - mae: 2.3381 - val_loss: 1.8036 - val_mae: 1.8036
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4698 - mae: 2.4698 - val_loss: 1.8443 - val_mae: 1.8443
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1309 - mae: 2.1309 - val_loss: 1.6727 - val_mae: 1.6727
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2239 - mae: 2.2239 - val_loss: 1.6271 - val_mae: 1.6271
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2162 - mae: 2.2162 - val_loss: 1.6338 - val_mae: 1.6338
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0317 - mae: 2.0317 - val_loss: 1.5943 - val_mae: 1.5943
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.0640 - mae: 2.0640 - val_loss: 1.6409 - val_mae: 1.6409
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9921 - mae: 1.9921 - val_loss: 1.7227 - val_mae: 1.7227
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.9119 - mae: 1.9119 - val_loss: 1.7363 - val_mae: 1.7363
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.1039 - mae: 2.1039 - val_loss: 1.7871 - val_mae: 1.7871
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0410 - mae: 2.0410 - val_loss: 1.8173 - val_mae: 1.8173
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9430 - mae: 1.9430 - val_loss: 1.7960 - val_mae: 1.7960
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2202 - mae: 2.2202 - val_loss: 1.7284 - val_mae: 1.7284
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8932 - mae: 1.8932 - val_loss: 1.6652 - val_mae: 1.6652
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7393 - mae: 1.7393 - val_loss: 1.5127 - val_mae: 1.5127
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7911 - mae: 1.7911 - val_loss: 1.4636 - val_mae: 1.4636
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8772 - mae: 1.8772 - val_loss: 1.5085 - val_mae: 1.5085
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7742 - mae: 1.7742 - val_loss: 1.6918 - val_mae: 1.6918
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1800 - mae: 2.1800 - val_loss: 1.8422 - val_mae: 1.8422
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8429 - mae: 1.8429 - val_loss: 1.8289 - val_mae: 1.8289
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9925 - mae: 1.9925 - val_loss: 1.7180 - val_mae: 1.7180
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8919 - mae: 1.8919 - val_loss: 1.6105 - val_mae: 1.6105
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7250 - mae: 1.7250 - val_loss: 1.6323 - val_mae: 1.6323
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7382 - mae: 1.7382 - val_loss: 1.5415 - val_mae: 1.5415
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8692 - mae: 1.8692 - val_loss: 1.4783 - val_mae: 1.4783
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7401 - mae: 1.7401 - val_loss: 1.4085 - val_mae: 1.4085
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8823 - mae: 1.8823 - val_loss: 1.3697 - val_mae: 1.3697
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6951 - mae: 1.6951 - val_loss: 1.4559 - val_mae: 1.4559
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7471 - mae: 1.7471 - val_loss: 1.5189 - val_mae: 1.5189
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6383 - mae: 1.6383 - val_loss: 1.4797 - val_mae: 1.4797
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8582 - mae: 1.8582 - val_loss: 1.4860 - val_mae: 1.4860
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6244 - mae: 1.6244 - val_loss: 1.5705 - val_mae: 1.5705
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7688 - mae: 1.7688 - val_loss: 1.6940 - val_mae: 1.6940
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6400 - mae: 1.6400 - val_loss: 1.5649 - val_mae: 1.5649

# %%
y_pred = model.predict(X_test) # 결과 = 확률
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
# 그래프 그리기용 데이터 저장
loss = history.history['loss']
val_loss = history.history['val_loss']
mae = history.history['mae']
val_mae = history.history['val_mae']

# %%
# 학습 과정에서 손실(loss)이 어떻게 변하는지 시각화

import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error


loss = history.history['loss'] # loss = 훈련 데이터 오차 /
val_loss = history.history['val_loss'] # val_loss = 검증 데이터 오차
# history는 model.fit() 결과

mae = history.history['mae']
val_mae = history.history['val_mae'] # 결과 척

epochs = range(1, len(loss) + 1) # x축 만들기

plt.plot(epochs, loss, 'y', label='Training loss') # 훈련 데이터 손실
# x축: epoch y축: loss 'y': 노란색
plt.plot(epochs, val_loss, 'r', label='Validation loss') # 검증 데이터 손실
# 'r': 빨간색
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(epochs, mae, 'y', label='Training MAE')
plt.plot(epochs, val_mae, 'r', label='Validation MAE')
plt.title('Training and validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# MAE : 1.4234573135375976
# MSE : 3.669060735042585
# RMSE: 1.9154792442212953
