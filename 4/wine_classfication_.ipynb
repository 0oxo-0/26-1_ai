# %%
# 데이터 불러오기

import pandas as pd
import numpy as np

path = '/content/drive/MyDrive/Colab Notebooks/wine.csv'
df = pd.read_csv(path)

# %%
# 데이터 출력해서 확인
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
#label, feature 데이터 입력하

y=df['Wine']

Y = pd.get_dummies(y).values # 원-핫 인코딩, 숫자 크기 의미 제거

X=df.drop('Wine',axis=1)

# %%
y.value_counts()
X.head()
# Out:
#    Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
# numpy 변환
X = X.values # 엑셀 형태 → 숫자 배열로 변환하기 위해 사

# 정규화 (데이터를 비슷한 범위로 맞추는 작업)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.25, random_state=0
)

# %%
from tensorflow.keras import layers, models
# 층(layer)을 순서대로 쌓는 모델, 입력 → 은닉층 → 출력층으로 일직선 구조

model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)), # 첫 번째 층 (입력층 + 은닉층),
    # 뉴런(노드) 64개, 입력 데이터의 컬럼 개수, activation="relu" <- 활성화 함수
    layers.Dropout(0.3), # 30% 뉴런을 랜덤으로 off > 과적합 방지
    layers.Dense(32, activation="relu"),# 두 번째 은닉층, 뉴런을 64 → 32로 줄이면서 중요한 정보만 남김
    layers.Dense(Y.shape[1], activation="softmax") # 출력층
    # Y.shape[1] = 클래스 개수, softmax = 확률로 변환
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# * 과적합(Overfitting)은 모델이 학습 데이터에만 과도하게 맞춰져 실제 데이터(검증 데이터)에 대한 일반화 능력이 떨어지는 현상

# %%
# 컴파일
model.compile(
    optimizer="adam", # 가중치 업데이트 방법, 자동으로 학습률 조정
    loss="categorical_crossentropy", # 손실 함수, “정답 vs 예측 확률 차이”
    metrics=["accuracy"] # 정확도 측정
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 모델학습
history = model.fit(
    X_train, y_train,
    validation_split=0.2, # 학습 데이터 중 20%를 검증용으로 사용
    epochs=50, # 전체 데이터를 50번 반복 학습
    batch_size=16, # 한 번에 16개씩 학습
    verbose=1 # 학습 과정 출력
)
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.3679 - loss: 1.1208 - val_accuracy: 0.5556 - val_loss: 0.9849
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5189 - loss: 0.9592 - val_accuracy: 0.7037 - val_loss: 0.8234
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7170 - loss: 0.7995 - val_accuracy: 0.8519 - val_loss: 0.6921
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8396 - loss: 0.6448 - val_accuracy: 0.8519 - val_loss: 0.5804
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8208 - loss: 0.5849 - val_accuracy: 0.8519 - val_loss: 0.4884
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8774 - loss: 0.4881 - val_accuracy: 0.8519 - val_loss: 0.4124
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9057 - loss: 0.3914 - val_accuracy: 0.8519 - val_loss: 0.3513
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9151 - loss: 0.3185 - val_accuracy: 0.8519 - val_loss: 0.3030
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9623 - loss: 0.2958 - val_accuracy: 0.9259 - val_loss: 0.2665
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9528 - loss: 0.2577 - val_accuracy: 0.9259 - val_loss: 0.2374
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9340 - loss: 0.2365 - val_accuracy: 0.9630 - val_loss: 0.2167
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9717 - loss: 0.2004 - val_accuracy: 0.9630 - val_loss: 0.2003
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9623 - loss: 0.1860 - val_accuracy: 0.9630 - val_loss: 0.1827
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9340 - loss: 0.1830 - val_accuracy: 0.9630 - val_loss: 0.1687
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9811 - loss: 0.1351 - val_accuracy: 0.9630 - val_loss: 0.1579
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9811 - loss: 0.1300 - val_accuracy: 0.9630 - val_loss: 0.1502
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.1270 - val_accuracy: 0.9630 - val_loss: 0.1435
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9717 - loss: 0.1216 - val_accuracy: 0.9630 - val_loss: 0.1401
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0835 - val_accuracy: 0.9630 - val_loss: 0.1380
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0751 - val_accuracy: 0.9630 - val_loss: 0.1350
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9717 - loss: 0.1005 - val_accuracy: 0.9630 - val_loss: 0.1325
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0636 - val_accuracy: 0.9630 - val_loss: 0.1320
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9717 - loss: 0.0808 - val_accuracy: 0.9630 - val_loss: 0.1311
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9811 - loss: 0.0642 - val_accuracy: 0.9630 - val_loss: 0.1282
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9811 - loss: 0.0685 - val_accuracy: 0.9630 - val_loss: 0.1259
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9717 - loss: 0.0753 - val_accuracy: 0.9630 - val_loss: 0.1237
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0595 - val_accuracy: 0.9630 - val_loss: 0.1179
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9717 - loss: 0.0693 - val_accuracy: 0.9630 - val_loss: 0.1152
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0505 - val_accuracy: 0.9630 - val_loss: 0.1163
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0370 - val_accuracy: 0.9630 - val_loss: 0.1194
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - loss: 0.0484 - val_accuracy: 0.9630 - val_loss: 0.1206
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0441 - val_accuracy: 0.9630 - val_loss: 0.1219
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0357 - val_accuracy: 0.9630 - val_loss: 0.1244
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0417 - val_accuracy: 0.9630 - val_loss: 0.1297
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0388 - val_accuracy: 0.9630 - val_loss: 0.1324
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9811 - loss: 0.0575 - val_accuracy: 0.9630 - val_loss: 0.1280
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 0.9630 - val_loss: 0.1294
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0453 - val_accuracy: 0.9630 - val_loss: 0.1285
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.9630 - val_loss: 0.1295
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0261 - val_accuracy: 0.9630 - val_loss: 0.1368
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - loss: 0.0375 - val_accuracy: 0.9630 - val_loss: 0.1415
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.9630 - val_loss: 0.1411
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9906 - loss: 0.0285 - val_accuracy: 0.9630 - val_loss: 0.1396
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0291 - val_accuracy: 0.9630 - val_loss: 0.1418
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0194 - val_accuracy: 0.9630 - val_loss: 0.1432
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 0.9630 - val_loss: 0.1405
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0213 - val_accuracy: 0.9630 - val_loss: 0.1401
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0325 - val_accuracy: 0.9630 - val_loss: 0.1438
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - loss: 0.0266 - val_accuracy: 0.9630 - val_loss: 0.1403
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.9630 - val_loss: 0.1394

# %%
y_pred = model.predict(X_test) # 결과 = 확률

y_test_class = np.argmax(y_test,axis=1) # 원-핫 → 숫자
y_pred_class = np.argmax(y_pred,axis=1) # 확률 → 예측 클래스
# 예시 =>
# np.argmax([0,0,1]) → 2
# np.argmax([0.1,0.2,0.7]) → 2
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
# 그래프 그리기용 데이터 저장
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %%
# 학습 과정에서 손실(loss)이 어떻게 변하는지 시각화

import matplotlib.pyplot as plt
import seaborn as sns

loss = history.history['loss'] # loss = 훈련 데이터 오차 /
val_loss = history.history['val_loss'] # val_loss = 검증 데이터 오차
# history는 model.fit() 결과
epochs = range(1, len(loss) + 1) # x축 만들기

plt.plot(epochs, loss, 'y', label='Training loss') # 훈련 데이터 손실
# x축: epoch y축: loss 'y': 노란색
plt.plot(epochs, val_loss, 'r', label='Validation loss') # 검증 데이터 손실
# 'r': 빨간색
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy'] # 훈련 데이터 정확도
val_acc = history.history['val_accuracy'] # 검증 데이터 정확도
plt.plot(epochs, acc, 'y', label='Training acc') # 훈련 정확도 (노란색)
plt.plot(epochs, val_acc, 'r', label='Validation acc') # 검증 정확도 (빨간색)
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# [[16  0  0]
#  [ 0 21  0]
#  [ 0  0  8]]
